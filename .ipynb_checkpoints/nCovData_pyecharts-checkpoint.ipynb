# %%
import numpy as np
import pandas as pd
import requests
import json
from pyecharts.charts import Map
from pyecharts import options as opts

# %%
def get_data(url):
    '''从url读取数据，返回json格式data'''
    req = requests.get(url)
    data = json.loads(req.json()['data'])
    return data

# %%
def get_data_countries(data):
    '''从data中提取国家数据，返回json列表'''
    data_countries = []
    for country in data['areaTree']:
        data_country = {'name': country['name']}
        for key, value in country['total'].items():
            data_country[key] = value
        data_countries.append(data_country)
    return data_countries

# %%
def get_data_provinces(data):
    '''从data的中国数据中提取省份数据，返回json列表'''
    data_provinces = []
    for province in data['areaTree'][0]['children']:
        data_province = {'name': province['name']}
        for key, value in province['total'].items():
            data_province[key] = value
        data_provinces.append(data_province)
    return data_provinces

# %%
url = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5'
data = get_data(url)
updateTime = data['lastUpdateTime']
data_countries = get_data_countries(data)
data_provinces = get_data_provinces(data)

# %%
china_map = Map()

# %%
china_map.add('确诊人数', [(z['name'], z['confirm']) for z in data_provinces])

# %%
china_map.set_global_opts(
    title_opts=opts.TitleOpts(title="Map-VisualMap（分段型）"),
    visualmap_opts=opts.VisualMapOpts(is_piecewise=True,
                                      pieces=[{
                                          "min": 0,
                                          "max": 100,
                                          "label": "0-100"
                                      }, {
                                          "min": 101,
                                          "max": 500,
                                          "label": "100-500"
                                      }, {
                                          "min": 501,
                                          "max": 1000,
                                          "label": "500-1000"
                                      }, {
                                          "min": 1001,
                                          "max": 2000,
                                          "label": "1000-2000"
                                      }, {
                                          "min": 2001,
                                          "label": ">2000"
                                      }]))

# %%
china_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="4152f010cf684e52885ff8708fbfa767" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_4152f010cf684e52885ff8708fbfa767 = echarts.init(
#                     document.getElementById('4152f010cf684e52885ff8708fbfa767'), 'white', {renderer: 'canvas'});
#                 var option_4152f010cf684e52885ff8708fbfa767 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u786e\u8bca\u4eba\u6570",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 62031
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1332
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1265
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1175
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 1010
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 987
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 934
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 631
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 560
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 546
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 520
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 476
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 395
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 334
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 307
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 293
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 245
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 245
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 173
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 168
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 146
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 131
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 130
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 121
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 91
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 91
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 76
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 71
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 67
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 24
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u786e\u8bca\u4eba\u6570"
#             ],
#             "selected": {
#                 "\u786e\u8bca\u4eba\u6570": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-VisualMap\uff08\u5206\u6bb5\u578b\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0,
#         "pieces": [
#             {
#                 "min": 0,
#                 "max": 100,
#                 "label": "0-100"
#             },
#             {
#                 "min": 101,
#                 "max": 500,
#                 "label": "100-500"
#             },
#             {
#                 "min": 501,
#                 "max": 1000,
#                 "label": "500-1000"
#             },
#             {
#                 "min": 1001,
#                 "max": 2000,
#                 "label": "1000-2000"
#             },
#             {
#                 "min": 2001,
#                 "label": ">2000"
#             }
#         ]
#     }
# };
#                 chart_4152f010cf684e52885ff8708fbfa767.setOption(option_4152f010cf684e52885ff8708fbfa767);
#         });
#     </script>

# %%
from nCovData import nCovData
from pyecharts.charts import Line

# %%
data=nCovData('csv/DXYArea.csv')

# %%
data_wuhan=data.get_df_by_cities('武汉')

# %%
data_wuhan['city_increase_confirmed','武汉'].head()
# Out:
# updateTime
# 2020-01-24      0.0
# 2020-01-25     77.0
# 2020-01-26     46.0
# 2020-01-27     80.0
# 2020-01-28    892.0
# Name: (city_increase_confirmed, 武汉), dtype: float64

# %%
line = (Line().add_xaxis(
    data_wuhan['city_increase_confirmed'].index.to_list()).add_yaxis(
        '武汉',
        data_wuhan['city_increase_confirmed', '武汉'].to_list()).set_global_opts(
            tooltip_opts=opts.TooltipOpts(axis_pointer_type='cross')))

# %%
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2b62f0f966c74fe2b6077cfbc2a6bf21" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2b62f0f966c74fe2b6077cfbc2a6bf21 = echarts.init(
#                     document.getElementById('2b62f0f966c74fe2b6077cfbc2a6bf21'), 'white', {renderer: 'canvas'});
#                 var option_2b62f0f966c74fe2b6077cfbc2a6bf21 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u6b66\u6c49",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2020-01-24",
#                     0.0
#                 ],
#                 [
#                     "2020-01-25",
#                     77.0
#                 ],
#                 [
#                     "2020-01-26",
#                     46.0
#                 ],
#                 [
#                     "2020-01-27",
#                     80.0
#                 ],
#                 [
#                     "2020-01-28",
#                     892.0
#                 ],
#                 [
#                     "2020-01-29",
#                     315.0
#                 ],
#                 [
#                     "2020-01-30",
#                     356.0
#                 ],
#                 [
#                     "2020-01-31",
#                     378.0
#                 ],
#                 [
#                     "2020-02-01",
#                     576.0
#                 ],
#                 [
#                     "2020-02-02",
#                     894.0
#                 ],
#                 [
#                     "2020-02-03",
#                     1033.0
#                 ],
#                 [
#                     "2020-02-04",
#                     1242.0
#                 ],
#                 [
#                     "2020-02-05",
#                     1967.0
#                 ],
#                 [
#                     "2020-02-06",
#                     1766.0
#                 ],
#                 [
#                     "2020-02-07",
#                     1501.0
#                 ],
#                 [
#                     "2020-02-08",
#                     1985.0
#                 ],
#                 [
#                     "2020-02-09",
#                     1379.0
#                 ],
#                 [
#                     "2020-02-10",
#                     1920.0
#                 ],
#                 [
#                     "2020-02-11",
#                     1552.0
#                 ],
#                 [
#                     "2020-02-12",
#                     1104.0
#                 ],
#                 [
#                     "2020-02-13",
#                     13436.0
#                 ],
#                 [
#                     "2020-02-14",
#                     2997.0
#                 ],
#                 [
#                     "2020-02-15",
#                     1923.0
#                 ],
#                 [
#                     "2020-02-16",
#                     1548.0
#                 ],
#                 [
#                     "2020-02-17",
#                     1690.0
#                 ],
#                 [
#                     "2020-02-18",
#                     1600.0
#                 ],
#                 [
#                     "2020-02-19",
#                     1660.0
#                 ],
#                 [
#                     "2020-02-20",
#                     615.0
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u6b66\u6c49"
#             ],
#             "selected": {
#                 "\u6b66\u6c49": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2020-01-24",
#                 "2020-01-25",
#                 "2020-01-26",
#                 "2020-01-27",
#                 "2020-01-28",
#                 "2020-01-29",
#                 "2020-01-30",
#                 "2020-01-31",
#                 "2020-02-01",
#                 "2020-02-02",
#                 "2020-02-03",
#                 "2020-02-04",
#                 "2020-02-05",
#                 "2020-02-06",
#                 "2020-02-07",
#                 "2020-02-08",
#                 "2020-02-09",
#                 "2020-02-10",
#                 "2020-02-11",
#                 "2020-02-12",
#                 "2020-02-13",
#                 "2020-02-14",
#                 "2020-02-15",
#                 "2020-02-16",
#                 "2020-02-17",
#                 "2020-02-18",
#                 "2020-02-19",
#                 "2020-02-20"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_2b62f0f966c74fe2b6077cfbc2a6bf21.setOption(option_2b62f0f966c74fe2b6077cfbc2a6bf21);
#         });
#     </script>
