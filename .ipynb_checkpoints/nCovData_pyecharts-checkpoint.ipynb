# %%
import numpy as np
import pandas as pd
import requests
import json
from pyecharts.charts import Map
from pyecharts import options as opts

# %%
def get_data(url):
    '''从url读取数据，返回json格式data'''
    req = requests.get(url)
    data = json.loads(req.json()['data'])
    return data

# %%
def get_data_countries(data):
    '''从data中提取国家数据，返回json列表'''
    data_countries = []
    for country in data['areaTree']:
        data_country = {'name': country['name']}
        for key, value in country['total'].items():
            data_country[key] = value
        data_countries.append(data_country)
    return data_countries

# %%
def get_data_provinces(data):
    '''从data的中国数据中提取省份数据，返回json列表'''
    data_provinces = []
    for province in data['areaTree'][0]['children']:
        data_province = {'name': province['name']}
        for key, value in province['total'].items():
            data_province[key] = value
        data_provinces.append(data_province)
    return data_provinces

# %%
url = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5_test'
data = get_data(url)
updateTime = data['lastUpdateTime']
data_countries = get_data_countries(data)
data_provinces = get_data_provinces(data)

# %%
china_map = Map()

# %%
china_map.add('确诊人数', [(z['name'], z['confirm']) for z in data_provinces])

# %%
china_map.set_global_opts(
    title_opts=opts.TitleOpts(title="Map-VisualMap（分段型）"),
    visualmap_opts=opts.VisualMapOpts(is_piecewise=True,
                                      pieces=[{
                                          "min": 0,
                                          "max": 100,
                                          "label": "0-100"
                                      }, {
                                          "min": 101,
                                          "max": 500,
                                          "label": "100-500"
                                      }, {
                                          "min": 501,
                                          "max": 1000,
                                          "label": "500-1000"
                                      }, {
                                          "min": 1001,
                                          "max": 2000,
                                          "label": "1000-2000"
                                      }, {
                                          "min": 2001,
                                          "label": ">2000"
                                      }]))

# %%
china_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="bcde1ebf7b1c42408d09a9c0d5e807e9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_bcde1ebf7b1c42408d09a9c0d5e807e9 = echarts.init(
#                     document.getElementById('bcde1ebf7b1c42408d09a9c0d5e807e9'), 'white', {renderer: 'canvas'});
#                 var option_bcde1ebf7b1c42408d09a9c0d5e807e9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u786e\u8bca\u4eba\u6570",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 56249
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1316
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1231
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1167
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 1004
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 962
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 925
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 617
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 547
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 537
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 481
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 445
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 380
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 328
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 300
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 287
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 237
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 236
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 169
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 162
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 144
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 128
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 124
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 120
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 90
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 89
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 71
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 56
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u786e\u8bca\u4eba\u6570"
#             ],
#             "selected": {
#                 "\u786e\u8bca\u4eba\u6570": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-VisualMap\uff08\u5206\u6bb5\u578b\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0,
#         "pieces": [
#             {
#                 "min": 0,
#                 "max": 100,
#                 "label": "0-100"
#             },
#             {
#                 "min": 101,
#                 "max": 500,
#                 "label": "100-500"
#             },
#             {
#                 "min": 501,
#                 "max": 1000,
#                 "label": "500-1000"
#             },
#             {
#                 "min": 1001,
#                 "max": 2000,
#                 "label": "1000-2000"
#             },
#             {
#                 "min": 2001,
#                 "label": ">2000"
#             }
#         ]
#     }
# };
#                 chart_bcde1ebf7b1c42408d09a9c0d5e807e9.setOption(option_bcde1ebf7b1c42408d09a9c0d5e807e9);
#         });
#     </script>
