# %%
import numpy as np
import pandas as pd
import requests
import json
from pyecharts.charts import Map
from pyecharts import options as opts

# %%
def get_data(url):
    '''从url读取数据，返回json格式data'''
    req = requests.get(url)
    data = json.loads(req.json()['data'])
    return data

# %%
def get_data_countries(data):
    '''从data中提取国家数据，返回json列表'''
    data_countries = []
    for country in data['areaTree']:
        data_country = {'name': country['name']}
        for key, value in country['total'].items():
            data_country[key] = value
        data_countries.append(data_country)
    return data_countries

# %%
def get_data_provinces(data):
    '''从data的中国数据中提取省份数据，返回json列表'''
    data_provinces = []
    for province in data['areaTree'][0]['children']:
        data_province = {'name': province['name']}
        for key, value in province['total'].items():
            data_province[key] = value
        data_provinces.append(data_province)
    return data_provinces

# %%
url = 'https://view.inews.qq.com/g2/getOnsInfo?name=disease_h5'
data = get_data(url)
updateTime = data['lastUpdateTime']
data_countries = get_data_countries(data)
data_provinces = get_data_provinces(data)

# %%
china_map = Map()

# %%
china_map.add('确诊人数', [(z['name'], z['confirm']) for z in data_provinces])

# %%
china_map.set_global_opts(
    title_opts=opts.TitleOpts(title="Map-VisualMap（分段型）"),
    visualmap_opts=opts.VisualMapOpts(is_piecewise=True,
                                      pieces=[{
                                          "min": 0,
                                          "max": 100,
                                          "label": "0-100"
                                      }, {
                                          "min": 101,
                                          "max": 500,
                                          "label": "100-500"
                                      }, {
                                          "min": 501,
                                          "max": 1000,
                                          "label": "500-1000"
                                      }, {
                                          "min": 1001,
                                          "max": 2000,
                                          "label": "1000-2000"
                                      }, {
                                          "min": 2001,
                                          "label": ">2000"
                                      }]))

# %%
china_map.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="979f93edd4b04e499b0cea321b4c7085" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_979f93edd4b04e499b0cea321b4c7085 = echarts.init(
#                     document.getElementById('979f93edd4b04e499b0cea321b4c7085'), 'white', {renderer: 'canvas'});
#                 var option_979f93edd4b04e499b0cea321b4c7085 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u786e\u8bca\u4eba\u6570",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 62662
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1333
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 1267
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1203
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 1011
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 988
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 934
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 748
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 631
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 567
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 525
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 479
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 396
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 334
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 308
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 293
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 246
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 245
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 174
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 168
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 146
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 132
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 131
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 121
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 91
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 91
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 76
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 71
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 68
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 24
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 18
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 10
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 1
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u786e\u8bca\u4eba\u6570"
#             ],
#             "selected": {
#                 "\u786e\u8bca\u4eba\u6570": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "Map-VisualMap\uff08\u5206\u6bb5\u578b\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0,
#         "pieces": [
#             {
#                 "min": 0,
#                 "max": 100,
#                 "label": "0-100"
#             },
#             {
#                 "min": 101,
#                 "max": 500,
#                 "label": "100-500"
#             },
#             {
#                 "min": 501,
#                 "max": 1000,
#                 "label": "500-1000"
#             },
#             {
#                 "min": 1001,
#                 "max": 2000,
#                 "label": "1000-2000"
#             },
#             {
#                 "min": 2001,
#                 "label": ">2000"
#             }
#         ]
#     }
# };
#                 chart_979f93edd4b04e499b0cea321b4c7085.setOption(option_979f93edd4b04e499b0cea321b4c7085);
#         });
#     </script>

# %%
from nCovData import nCovData
from pyecharts.charts import Line

# %%
data=nCovData('csv/DXYArea.csv')

# %%
data_cities=data.get_df_by_cities('黄石','鄂州')

# %%
line = Line()
line.add_xaxis(data_cities['city_increase_confirmed'].index.tolist())
line.add_yaxis('黄石', data_cities['city_increase_confirmed','黄石'].tolist())
line.add_yaxis('鄂州', data_cities['city_increase_confirmed','鄂州'].tolist())
line.set_global_opts(tooltip_opts=opts.TooltipOpts(axis_pointer_type='cross'))

# %%
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0e54c4a5849d4e64b3f2d3cbd6008150" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0e54c4a5849d4e64b3f2d3cbd6008150 = echarts.init(
#                     document.getElementById('0e54c4a5849d4e64b3f2d3cbd6008150'), 'white', {renderer: 'canvas'});
#                 var option_0e54c4a5849d4e64b3f2d3cbd6008150 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u9ec4\u77f3",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2020-01-25",
#                     0.0
#                 ],
#                 [
#                     "2020-01-26",
#                     0.0
#                 ],
#                 [
#                     "2020-01-27",
#                     5.0
#                 ],
#                 [
#                     "2020-01-28",
#                     17.0
#                 ],
#                 [
#                     "2020-01-29",
#                     33.0
#                 ],
#                 [
#                     "2020-01-30",
#                     27.0
#                 ],
#                 [
#                     "2020-01-31",
#                     55.0
#                 ],
#                 [
#                     "2020-02-01",
#                     41.0
#                 ],
#                 [
#                     "2020-02-02",
#                     43.0
#                 ],
#                 [
#                     "2020-02-03",
#                     82.0
#                 ],
#                 [
#                     "2020-02-04",
#                     71.0
#                 ],
#                 [
#                     "2020-02-05",
#                     104.0
#                 ],
#                 [
#                     "2020-02-06",
#                     57.0
#                 ],
#                 [
#                     "2020-02-07",
#                     69.0
#                 ],
#                 [
#                     "2020-02-08",
#                     68.0
#                 ],
#                 [
#                     "2020-02-09",
#                     57.0
#                 ],
#                 [
#                     "2020-02-10",
#                     45.0
#                 ],
#                 [
#                     "2020-02-11",
#                     30.0
#                 ],
#                 [
#                     "2020-02-12",
#                     39.0
#                 ],
#                 [
#                     "2020-02-13",
#                     37.0
#                 ],
#                 [
#                     "2020-02-14",
#                     32.0
#                 ],
#                 [
#                     "2020-02-15",
#                     37.0
#                 ],
#                 [
#                     "2020-02-16",
#                     8.0
#                 ],
#                 [
#                     "2020-02-17",
#                     0.0
#                 ],
#                 [
#                     "2020-02-18",
#                     -3.0
#                 ],
#                 [
#                     "2020-02-19",
#                     0.0
#                 ],
#                 [
#                     "2020-02-20",
#                     -18.0
#                 ],
#                 [
#                     "2020-02-21",
#                     7.0
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u9102\u5dde",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2020-01-25",
#                     0.0
#                 ],
#                 [
#                     "2020-01-26",
#                     0.0
#                 ],
#                 [
#                     "2020-01-27",
#                     19.0
#                 ],
#                 [
#                     "2020-01-28",
#                     37.0
#                 ],
#                 [
#                     "2020-01-29",
#                     27.0
#                 ],
#                 [
#                     "2020-01-30",
#                     39.0
#                 ],
#                 [
#                     "2020-01-31",
#                     66.0
#                 ],
#                 [
#                     "2020-02-01",
#                     38.0
#                 ],
#                 [
#                     "2020-02-02",
#                     51.0
#                 ],
#                 [
#                     "2020-02-03",
#                     28.0
#                 ],
#                 [
#                     "2020-02-04",
#                     26.0
#                 ],
#                 [
#                     "2020-02-05",
#                     50.0
#                 ],
#                 [
#                     "2020-02-06",
#                     41.0
#                 ],
#                 [
#                     "2020-02-07",
#                     48.0
#                 ],
#                 [
#                     "2020-02-08",
#                     98.0
#                 ],
#                 [
#                     "2020-02-09",
#                     70.0
#                 ],
#                 [
#                     "2020-02-10",
#                     86.0
#                 ],
#                 [
#                     "2020-02-11",
#                     65.0
#                 ],
#                 [
#                     "2020-02-12",
#                     71.0
#                 ],
#                 [
#                     "2020-02-13",
#                     204.0
#                 ],
#                 [
#                     "2020-02-14",
#                     60.0
#                 ],
#                 [
#                     "2020-02-15",
#                     67.0
#                 ],
#                 [
#                     "2020-02-16",
#                     38.0
#                 ],
#                 [
#                     "2020-02-17",
#                     44.0
#                 ],
#                 [
#                     "2020-02-18",
#                     65.0
#                 ],
#                 [
#                     "2020-02-19",
#                     4.0
#                 ],
#                 [
#                     "2020-02-20",
#                     -5.0
#                 ],
#                 [
#                     "2020-02-21",
#                     5.0
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaSty

# %%
from pyecharts.charts import Bar

# %%
bar=Bar()

# %%
bar.add_xaxis(data_cities['city_confirmedCount'].index.tolist())

# %%
bar.add_yaxis('黄石',data_cities['city_confirmedCount','黄石'].tolist())
bar.add_yaxis('鄂州',data_cities['city_confirmedCount','鄂州'].tolist())

# %%
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f6cbcfdcde38441c9b44a3c26fd31fdf" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f6cbcfdcde38441c9b44a3c26fd31fdf = echarts.init(
#                     document.getElementById('f6cbcfdcde38441c9b44a3c26fd31fdf'), 'white', {renderer: 'canvas'});
#                 var option_f6cbcfdcde38441c9b44a3c26fd31fdf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u9ec4\u77f3",
#             "data": [
#                 31,
#                 31,
#                 36,
#                 53,
#                 86,
#                 113,
#                 168,
#                 209,
#                 252,
#                 334,
#                 405,
#                 509,
#                 566,
#                 635,
#                 703,
#                 760,
#                 805,
#                 835,
#                 874,
#                 911,
#                 943,
#                 980,
#                 988,
#                 988,
#                 985,
#                 985,
#                 967,
#                 974
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u9102\u5dde",
#             "data": [
#                 1,
#                 1,
#                 20,
#                 57,
#                 84,
#                 123,
#                 189,
#                 227,
#                 278,
#                 306,
#                 332,
#                 382,
#                 423,
#                 471,
#                 569,
#                 639,
#                 725,
#                 790,
#                 861,
#                 1065,
#                 1125,
#                 1192,
#                 1230,
#                 1274,
#                 1339,
#                 1343,
#                 1338,
#                 1343
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u9ec4\u77f3",
#                 "\u9102\u5dde"
#             ],
#             "selected": {
#                 "\u9ec4\u77f3": true,
#                 "\u9102\u5dde": true
#             }
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "2020-01-25",
#                 "2020-01-26",
#                 "2020-01-27",
#                 "2020-01-28",
#                 "2020-01-29",
#                 "2020-01-30",
#                 "2020-01-31",
#                 "2020-02-01",
#                 "2020-02-02",
#                 "2020-02-03",
#                 "2020-02-04",
#                 "2020-02-05",
#                 "2020-02-06",
#                 "2020-02-07",
#                 "2020-02-08",
#                 "2020-02-09",
#                 "2020-02-10",
#                 "2020-02-11",
#                 "2020-02-12",
#                 "2020-02-13",
#                 "2020-02-14",
#                 "2020-02-15",
#                 "2020-02-16",
#                 "2020-02-17",
#                 "2020-02-18",
#                 "2020-02-19",
#                 "2020-02-20",
#                 "2020-02-21"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ]
# };
#                 chart_f6cbcfdcde38441c9b44a3c26fd31fdf.setOption(option_f6cbcfdcde38441c9b44a3c26fd31fdf);
#         });
#     </script>
