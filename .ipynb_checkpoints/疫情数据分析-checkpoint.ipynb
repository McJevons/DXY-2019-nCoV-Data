# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
# 根据指定列读取csv文件
data = pd.read_csv('csv/DXYArea.csv')[[
    'cityName', 'city_confirmedCount', 'city_suspectedCount',
    'city_curedCount', 'city_deadCount', 'updateTime'
]]

# %%
data_copy=data.copy()

# %%
# 删除非武汉的行
data.drop(data[data['cityName'] != '武汉'].index, inplace=True)

# %%
# updateTime格式处理
data['updateTime'] = data['updateTime'].map(lambda x: x[:10])

# %%
# 根据updateTime聚合数据，取最大值
data = data.groupby(['updateTime']).max()

# %%
# 计算每日确诊数，空值置为0
data['city_increase_confirmed']=data['city_confirmedCount'].diff(1).fillna(0)

# %%
data
# Out:
#            cityName  city_confirmedCount  city_suspectedCount  \
# updateTime
# 2020-01-24       武汉                  495                    0
# 2020-01-25       武汉                  572                    0
# 2020-01-26       武汉                  618                    0
# 2020-01-27       武汉                  698                    0
# 2020-01-28       武汉                 1590                    0
# 2020-01-29       武汉                 1905                    0
# 2020-01-30       武汉                 2261                    0
# 2020-01-31       武汉                 2639                    0
# 2020-02-01       武汉                 3215                    0
# 2020-02-02       武汉                 4109                    0
# 2020-02-03       武汉                 5142                    0
# 2020-02-04       武汉                 6384                    0
# 2020-02-05       武汉                 8351                    0
# 2020-02-06       武汉                10117                    0
# ...

# %%
data.plot()

# %%
data['city_increase_confirmed'].plot(kind='bar')

# %%
data_copy
# Out:
#       cityName  city_confirmedCount  city_suspectedCount  city_curedCount  \
# 0          万州区                   74                    0                3
# 1          云阳县                   20                    0                3
# 2         九龙坡区                   19                    0                0
# 3          江北区                   19                    0                0
# 4          渝中区                   19                    0                0
# ...        ...                  ...                  ...              ...
# 22699       昆明                    2                    0                0
# 22700       太原                    1                    0                0
# 22701       长春                    1                    0                0
# 22702      石家庄                    1                    0                0
# 22703       银川                    1                    0                0
#
#        city_deadCount               updateTime
# ...

# %%
data
# Out:
#            cityName  city_confirmedCount  city_suspectedCount  \
# updateTime
# 2020-01-24       武汉                  495                    0
# 2020-01-25       武汉                  572                    0
# 2020-01-26       武汉                  618                    0
# 2020-01-27       武汉                  698                    0
# 2020-01-28       武汉                 1590                    0
# 2020-01-29       武汉                 1905                    0
# 2020-01-30       武汉                 2261                    0
# 2020-01-31       武汉                 2639                    0
# 2020-02-01       武汉                 3215                    0
# 2020-02-02       武汉                 4109                    0
# 2020-02-03       武汉                 5142                    0
# 2020-02-04       武汉                 6384                    0
# 2020-02-05       武汉                 8351                    0
# 2020-02-06       武汉                10117                    0
# ...
